# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline\

# 한글 처리 (구글링)
# %config InlineBackend.figure_format = 'retina'
 
# !apt -qq -y install fonts-nanum
 
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()
# Out:
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 144465 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
import numpy as np
import pandas as pd

# %%
path = '/content/drive/My Drive/data_project'

# %%
re_hit_adv_day = pd.read_csv(path + '/은경s/kbreport_hit_advanced_day.csv', encoding='cp949')
re_hit_adv_day =re_hit_adv_day.drop('Unnamed: 0', axis = 1)
re_hit_adv_day.drop_duplicates(inplace=True)
re_hit_adv_day
# Out:
#         연도  월   일    팀명  경기  타석  ...  RC/27    wRC   SPD   wSB   wOBA  wRAA
# 0     2015  3  28    롯데   1  42  ...  10.92  10.43  5.63  0.36  0.479  5.04
# 1     2015  3  28    두산   1  43  ...  10.77   8.66  8.53  0.21  0.427  3.13
# 2     2015  3  28    삼성   1  42  ...   8.13   6.59  5.59  0.54  0.378  1.20
# 3     2015  3  28   KIA   1  34  ...   5.41   4.28  7.25  0.36  0.344 -0.09
# 4     2015  3  28  Hero   1  46  ...   4.30   4.56  3.56  0.36  0.315 -1.35
# ...    ... ..  ..   ...  ..  ..  ...    ...    ...   ...   ...    ...   ...
# 7863  2020  7  28    SK   1  41  ...   6.43   6.56  2.77  0.03  0.382  1.29
# 7864  2020  7  29    한화   1  49  ...   9.74   9.82  3.60  0.06  0.426  3.53
# 7865  2020  7  29    LG   1  45  ...  11.93  11.26  2.03  0.22  0.481  5.47
# 7866  2020  7  29    SK   1  44  ...  12.35  10.24  4.28  0.37  0.462  4.59
# 7867  2020  7  29    삼성   1  44  ...   7.39   8.18  3.14  0.21  0.410  2.53
#
# [7868 rows x 21 columns]

# %%
re_hit_adv_day.to_csv(path + '/은경s/kbreport_hit_advanced_day_수정.csv', encoding='cp949')

# %%
re_hit_main_day = pd.read_csv(path + '/은경s/kbreport_hit_main_day.csv', encoding='cp949')
re_hit_main_day =re_hit_main_day.drop('Unnamed: 0', axis = 1)
re_hit_main_day.drop_duplicates(inplace=True)
re_hit_main_day
# Out:
#         연도  월   일    팀명   R/G  득점  ...  BABIP     타율    출루율    장타율    OPS   wOBA
# 0     2015  3  28    롯데  12.0  12  ...  0.444  0.378  0.439  0.676  1.115  0.479
# 1     2015  3  28    두산   9.0   9  ...  0.323  0.343  0.429  0.571  1.000  0.427
# 2     2015  3  28    삼성   6.0   6  ...  0.394  0.342  0.405  0.421  0.826  0.378
# 3     2015  3  28   KIA   3.0   3  ...  0.280  0.267  0.324  0.467  0.791  0.344
# 4     2015  3  28  Hero   5.0   5  ...  0.194  0.200  0.304  0.400  0.704  0.315
# ...    ... ..  ..   ...   ...  ..  ...    ...    ...    ...    ...    ...    ...
# 8553  2020  5  26    SK   4.0   4  ...  0.280  0.219  0.306  0.219  0.525  0.246
# 8554  2020  5  26  Hero   2.0   2  ...  0.208  0.156  0.289  0.156  0.445  0.235
# 8555  2020  5  26    삼성   0.0   0  ...  0.200  0.138  0.242  0.172  0.414  0.210
# 8556  2020  5  26    KT   1.0   1  ...  0.235  0.129  0.182  0.129  0.311  0.155
# 8557  2020  5  26    한화   0.0   0  ...  0.120  0.107  0.167  0.107  0.274  0.140
#
# ...

# %%
re_hit_main_day.to_csv(path + '/은경s/kbreport_hit_main_day_수정.csv', encoding='cp949')

# %%
re_hit_std_day = pd.read_csv(path + '/은경s/kbreport_hit_standard_day.csv', encoding='cp949')
re_hit_std_day =re_hit_std_day.drop('Unnamed: 0', axis = 1)
re_hit_std_day.drop_duplicates(inplace=True)
re_hit_std_day
# Out:
#         연도  월   일  팀명  경기  타석  타수  안타  ...  사구  삼진  희생플라이  희생타  병살  도루  도실     타율
# 0     2015  3  28  롯데   1  42  37  14  ...   1   8      0    1   1   2   0  0.378
# 1     2015  3  28  KT   1  46  35  14  ...   1   8      1    2   1   1   0  0.400
# 2     2015  3  28  NC   1  38  31   9  ...   1   8      2    2   1   2   0  0.290
# 3     2015  3  28  한화   1  54  42  10  ...   1   7      1    4   0   4   0  0.238
# 4     2015  3  28  두산   1  43  35  12  ...   0   3      1    1   0   1   0  0.343
# ...    ... ..  ..  ..  ..  ..  ..  ..  ...  ..  ..    ...  ...  ..  ..  ..    ...
# 7863  2020  7  28  두산   1  38  36   9  ...   0   4      0    0   0   0   0  0.250
# 7864  2020  7  29  삼성   1  44  34   9  ...   2   7      0    0   1   1   0  0.265
# 7865  2020  7  29  한화   1  49  44  18  ...   1   7      1    1   1   0   0  0.409
# 7866  2020  7  29  LG   1  45  36  13  ...   1   7      0    0   2   1   0  0.361
# ...

# %%
re_hit_std_day.to_csv(path + '/은경s/kbreport_hit_standard_day_수정.csv', encoding='cp949')

# %%
re_pit_adv_day = pd.read_csv(path + '/은경s/kbreport_pit_advanced_day.csv', encoding='cp949')
re_pit_adv_day =re_pit_adv_day.drop('Unnamed: 0', axis = 1)
re_pit_adv_day.drop_duplicates(inplace=True)
re_pit_adv_day
# Out:
#         연도  월   일    팀명  경기  QS  ...  LOB%   ERA  RA9-WAR    FIP   kFIP   WAR
# 0     2015  3  28   KIA   1   1  ...  90.9   1.0     0.61   3.67   3.78  0.18
# 1     2015  3  28    삼성   1   1  ...  90.0   1.0     0.58   3.56   3.51  0.18
# 2     2015  3  28  Hero   1   0  ...  77.8   3.0     0.63   4.50   4.81  0.14
# 3     2015  3  28    두산   1   0  ...  71.4   4.0     0.20   3.56   3.52  0.27
# 4     2015  3  28    롯데   1   0  ...  69.3   9.0    -0.03   7.78   7.96  0.01
# ...    ... ..  ..   ...  ..  ..  ...   ...   ...      ...    ...    ...   ...
# 7863  2020  7  28    SK   1   0  ...  33.9  24.0    -0.89  13.67  14.05 -0.33
# 7864  2020  7  29    LG   1   0  ...  96.8   6.0     0.20   9.67   9.93 -0.17
# 7865  2020  7  29    한화   1   0  ...  74.1   7.0     0.05   8.34   8.69 -0.27
# 7866  2020  7  29    삼성   1   0  ...  48.5   5.0    -0.50   4.89   4.91  0.03
# 7867  2020  7  29    SK   1   0  ...  61.8  11.0    -0.39   9.45   9.74 -0.36
#
# [7868 rows x 24 columns]

# %%
re_pit_adv_day.to_csv(path + '/은경s/kbreport_pit_advanced_day_수정.csv', encoding='cp949')

# %%
re_pit_main_day = pd.read_csv(path + '/은경s/kbreport_pit_main_day.csv', encoding='cp949')
re_pit_main_day =re_pit_main_day.drop('Unnamed: 0', axis = 1)
re_pit_main_day.drop_duplicates(inplace=True)
re_pit_main_day
# Out:
#         연도  월   일    팀명  팀승  팀무  ...  LOB%   ERA  RA9-WAR   FIP  kFIP   WAR
# 0     2015  3  28    삼성   1   0  ...  90.0  1.00     0.58  3.56  3.50  0.18
# 1     2015  3  28   KIA   1   0  ...  90.9  1.00     0.61  3.67  3.78  0.18
# 2     2015  3  28  Hero   1   0  ...  77.8  3.00     0.63  4.50  4.81  0.14
# 3     2015  3  28    두산   1   0  ...  71.4  4.00     0.20  3.56  3.52  0.27
# 4     2015  3  28    롯데   1   0  ...  69.3  9.00    -0.03  7.78  7.95  0.01
# ...    ... ..  ..   ...  ..  ..  ...   ...   ...      ...   ...   ...   ...
# 7851  2020  7  26    두산   0   0  ...  55.6  2.00     0.21  2.56  2.35  0.27
# 7852  2020  7  26    NC   0   0  ...  86.2  3.38    -0.00  7.29  7.01 -0.03
# 7853  2020  7  26    삼성   0   0  ...  50.0  6.75    -0.10  3.92  4.11  0.16
# 7854  2020  7  26    한화   0   0  ...  58.8  7.00    -0.11  4.89  5.29  0.04
# 7855  2020  7  26    롯데   0   0  ...  55.6  9.00    -0.20  3.92  4.11  0.09
#
# [7856 rows x 20 columns]

# %%
re_pit_main_day.to_csv(path + '/은경s/kbreport_pit_main_day_수정.csv', encoding='cp949')

# %%
re_pit_std_day = pd.read_csv(path + '/은경s/kbreport_pit_standard_day.csv', encoding='cp949')
re_pit_std_day =re_pit_std_day.drop('Unnamed: 0', axis = 1)
re_pit_std_day.drop_duplicates(inplace=True)
re_pit_std_day
# Out:
#         연도  월   일    팀명  경기  승  패  세이브  ...  볼넷  고의4구  사구  폭투  보크  PK  도루  도실
# 0     2015  3  28    삼성   1  1  0    0  ...   5     0   0   0   0   0   0   1
# 1     2015  3  28   KIA   1  1  0    1  ...   4     0   0   1   0   0   0   0
# 2     2015  3  28  Hero   1  1  0    0  ...   7     0   1   0   0   0   4   0
# 3     2015  3  28    두산   1  1  0    0  ...   4     0   1   0   1   0   2   2
# 4     2015  3  28    롯데   1  1  0    0  ...   8     0   1   0   0   0   1   1
# ...    ... ..  ..   ...  .. .. ..  ...  ...  ..   ...  ..  ..  ..  ..  ..  ..
# 7863  2020  7  28    SK   1  0  1    0  ...   7     1   2   3   0   0   0   0
# 7864  2020  7  29    LG   1  1  0    0  ...   3     0   1   0   0   0   2   0
# 7865  2020  7  29    한화   1  1  0    0  ...   8     0   2   0   0   0   1   1
# 7866  2020  7  29    삼성   1  0  1    0  ...   3     0   1   0   0   0   0   0
# 7867  2020  7  29    SK   1  0  1    0  ...   8     0   1   0   0   1   1   0
#
# [7868 rows x 28 columns]

# %%
re_pit_std_day.to_csv(path + '/은경s/kbreport_pit_standard_day_수정.csv', encoding='cp949')
