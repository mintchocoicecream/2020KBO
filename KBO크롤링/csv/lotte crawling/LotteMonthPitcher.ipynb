# %%
from selenium import webdriver as wd
import pandas as pd

# %%
driver = wd.Chrome('C:/Users/sxxhn/Desktop/lotte/chromedriver.exe')

# %%
import time
for n in range(2):
    target_site = 'http://www.giantsclub.com/html/?pcode=296'
    driver.get(target_site)
    time.sleep(5)

# %%
YEARS = [ option.get_attribute('value')
 for option in driver.find_elements_by_css_selector('#year_p > option')
    if option.get_attribute('value') 
]
YEARS[:2]
# Out:
# ['2020', '2019']

# %%
data = list()
for year in YEARS[0:6]:
    year_sel = driver.find_element_by_id('year_p')
    year_sel.send_keys( year )
    driver.find_element_by_xpath('//*[@id="cont_wrapper"]/div/div[2]/div/form/input').click()
    time.sleep(5)
    
    # 데이터
    
    results = list()
    for td in driver.find_elements_by_css_selector('#tbl-rank > tbody > tr') :
        results.append(td.text.split())
        
    for i in range(0, len(results)) :
        if len(results[i]) == 18 :
            data.append({
                '연도' : year,
                '월' : results[i][0],
                '경기수' : results[i][1],
                '타수' : results[i][2],
                '피안타' : results[i][3],
                '자책점' : results[i][4],
                '승' : results[i][5],
                '패' : results[i][6],
                '세이브' : results[i][7],
                '홀드' : results[i][8],
                '이닝' : (results[i][9]+" "+results[i][10]),
                '탈삼진' : results[i][11],
                '볼넷' : results[i][12],
                '방어율' : results[i][13],
                '피홈런' : results[i][14],
                '사구' : results[i][15],
                '실점' : results[i][16],
                '피안타율' : results[i][17]
            })
        else :
            data.append({
                '연도' : year,
                '월' : results[i][0],
                '경기수' : results[i][1],
                '타수' : results[i][2],
                '피안타' : results[i][3],
                '자책점' : results[i][4],
                '승' : results[i][5],
                '패' : results[i][6],
                '세이브' : results[i][7],
                '홀드' : results[i][8],
                '이닝' : results[i][9],
                '탈삼진' : results[i][10],
                '볼넷' : results[i][11],
                '방어율' : results[i][12],
                '피홈런' : results[i][13],
                '사구' : results[i][14],
                '실점' : results[i][15],
                '피안타율' : results[i][16]
            })

# %%
df = pd.DataFrame(data)
df
# Out:
#       연도   월 경기수    타수  피안타  자책점   승   패 세이브  홀드       이닝  탈삼진   볼넷    방어율  \
# 0   2020  05  23   789  210  111  11  12   3  11  208 1/3  158   91   6.07
# 1   2020  06  23   779  205  102  12  11   4   9  205 2/3  158   56   5.61
# 2   2020  07  15   540  156   80   6   9   2   7  133 1/3   96   49   5.91
# 3   2019  03   8   330   87   56   3   6   0   3   81 2/3   79   46  10.82
# 4   2019  04  22   876  250  124  10  13   4  12  220 2/3  202  104   5.92
# 5   2019  05  27  1079  326  178  11  19   1   3  266 1/3  218  130   8.48
# 6   2019  06  24   839  221   81  10  12   4  12      222  183   85   3.46
# 7   2019  07  18   607  177   93   4  14   2   4      154  106   63   7.92
# 8   2019  08  25   852  242  112   9  15   4   4      218  162   72   6.06
# 9   2019  09  19   628  161   68   4  15   1   9      165  132   61   3.12
# 10  2019  10   1    35    8    1   0   1   0   0        9    9    3   0.64
# 11  2018  03   7   231   62   38   0   7   0   1       58   52   32  10.35
# 12  2018  04  22   756  208  119  12  10   6   7      198  196  107   7.52
# 13  2018  05  24   829  236  108  11  13   4  12      211  198   84   4.68
# 14  2018  06  25   907  245  141  12  11   2   7  231 2/3  213  107   9.93
