# %%
from selenium import webdriver as wd
import pandas as pd

# %%
driver = wd.Chrome('C:/Users/sxxhn/Desktop/lotte/chromedriver.exe')

# %%
import time
for n in range(2):
    target_site = 'http://www.giantsclub.com/html/?pcode=293'
    driver.get(target_site)
    time.sleep(5)

# %%
YEARS = [ option.get_attribute('value')
 for option in driver.find_elements_by_css_selector('#year_p > option')
    if option.get_attribute('value') 
]
YEARS[:2]
# Out:
# ['2020', '2019']

# %%
data = list()
for year in YEARS[0:6]:
    year_sel = driver.find_element_by_id('year_p')
    year_sel.send_keys( year )    
    driver.find_element_by_xpath('//*[@id="cont_wrapper"]/div/div[2]/div/form/input').click()
    time.sleep(5)
    
    # 데이터
    
    results = list()
    for td in driver.find_elements_by_css_selector('#tbl-rank > tbody > tr') :
        results.append(td.text.split())
        
    for i in range(0, len(results)) :
        if len(results[i]) == 18 :
            data.append({
                '연도' : year,
                '홈원정' : results[i][0],
                '경기수' : results[i][1],
                '타수' : results[i][2],
                '피안타' : results[i][3],
                '자책점' : results[i][4],
                '승' : results[i][5],
                '패' : results[i][6],
                '세이브' : results[i][7],
                '홀드' : results[i][8],
                '이닝' : (results[i][9]+" "+results[i][10]),
                '탈삼진' : results[i][11],
                '볼넷' : results[i][12],
                '방어율' : results[i][13],
                '피홈런' : results[i][14],
                '사구' : results[i][15],
                '실점' : results[i][16],
                '피안타율' : results[i][17]
            })
        else :
            data.append({
                '연도' : year,
                '홈원정' : results[i][0],
                '경기수' : results[i][1],
                '타수' : results[i][2],
                '피안타' : results[i][3],
                '자책점' : results[i][4],
                '승' : results[i][5],
                '패' : results[i][6],
                '세이브' : results[i][7],
                '홀드' : results[i][8],
                '이닝' : results[i][9],
                '탈삼진' : results[i][10],
                '볼넷' : results[i][11],
                '방어율' : results[i][12],
                '피홈런' : results[i][13],
                '사구' : results[i][14],
                '실점' : results[i][15],
                '피안타율' : results[i][16]
            })

# %%
df = pd.DataFrame(data)
df
# Out:
#       연도 홈원정 경기수    타수  피안타  자책점   승   패 세이브  홀드       이닝  탈삼진   볼넷   방어율 피홈런  \
# 0   2020  원정  32  1095  297  158  11  21   3  15  284 1/3  212  109  5.74  35
# 1   2020   홈  29  1013  274  135  18  11   6  12      263  200   87  6.76  36
# 2   2019  원정  72  2531  717  351  22  51   4  19  646 1/3  530  286  6.95  55
# 3   2019   홈  72  2715  755  362  29  44  12  28  690 1/3  561  278     9  72
# 4   2018  원정  72  2445  665  354  34  36  13  29  621 2/3  582  254  6.52  75
# 5   2018   홈  72  2616  745  417  34  38  16  35      662  582  294  7.42  91
# 6   2017  원정  72  2363  649  319  33  37  18  30  612 1/3  526  232  5.64  66
# 7   2017   홈  72  2435  668  313  43  24  19  30  627 1/3  520  238  4.29  86
# 8   2016  원정  72  2436  737  411  26  47  10  25  609 2/3  490  281  6.81  70
# 9   2016   홈  72  2514  732  372  40  32  17  33  641 1/3  506  292  6.65  88
# 10  2015  원정  72  2542  767  371  29  46  10  19  642 2/3  476  262  5.87  75
# 11  2015   홈  72  2639  745  384  37  37   9  28      678  565  248   5.2  99
#
#     사구   실점   피안타율
# 0   10  173  0.271
# 1   11  147  0.292
# 2   42  393  0.293
# 3   31  400  0.289
# 4   45  402  0.285
# 5   28  444  0.317
# 6   47  341  0.287
# 7   29  339  0.255
# 8   35  448  0.304
# 9   40  408  0.305
# 10  45  404  0.315
# 11  44  428  0.317

# %%
# 닫기 (창닫고, 프로세스도 종료)
driver.close()
driver.quit()
